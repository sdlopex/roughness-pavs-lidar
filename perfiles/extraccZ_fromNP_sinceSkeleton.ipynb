# %%
import os
import sys
import pandas as pd
import numpy as np
from descartes import PolygonPatch
import matplotlib.pyplot as plt
sys.path.insert(0, os.path.dirname(os.getcwd()))
import alphashape

import pdal
import trimesh
from shapely.geometry import Point, LineString
from scipy import interpolate, spatial
import geopandas as gpd
import networkx as nx

# %% [markdown]
# # Borde vía de NP de SR
# ## Concavo envolvente de los puntos en 2D de la SR: luego de clasificasdos automáticamente con DL

# %% [raw]
# "superficiesRodadura/iqmulus/sr_iqmulus.ply"
# "superficiesRodadura/npm3d_parisLille/lille2.ply"

# %%
ppl="""
    {
        "pipeline":[
            "superficiesRodadura/npm3d_parisLille/lille2.ply",
            {
            "type":"filters.decimation",
            "step": 20
            },
            {
            "type":"filters.info"
            }
        ]  
    }"""


#"/mnt/d/8_MSc/GEPMS/3_PavsLiDAR_IC/datasets/NPM3D/paris-lille/training_10_classes/lille2.ply"
# probar con diferentes valores de knn 

pipeline = pdal.Pipeline(ppl)
count = pipeline.execute()

# %%
print('numero de puntos de la nube cargada: '+str(count))
# Out:
# numero de puntos de la nube cargada: 590811

# %%
#print(pipeline.metadata)

# %%
dtst_ini=pipeline.arrays[0]
encbz_ini=pipeline.arrays[0].dtype.names

# %%
print('DATOS SUBIDOS CON PDAL\n')
print(encbz_ini)
print(dtst_ini[:3])
# Out:
# DATOS SUBIDOS CON PDAL
#
# ('X', 'Y', 'Z', 'scalar_class')
# [(-774.49053955, -752.46435547, 27.53279495, 2.0202e+08)
#  (-775.38812256, -752.41717529, 27.49207306, 2.0202e+08)
#  (-773.76525879, -753.42822266, 27.49519539, 2.0202e+08)]

# %%
enc_xy=('X', 'Y')

# %%
xy=np.zeros((len(dtst_ini),2))

# %%
for e in range(len(xy)):
    for i in range(len(enc_xy)):
        xy[e,i]=dtst_ini[e][encbz_ini.index(enc_xy[i])]

# %%
xy.shape
# Out:
# (590811, 2)

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*xy))
plt.show()

# %%
alpha_shape_via = alphashape.alphashape(xy, 2)

# %%
#areas=[i.area for i in list(alpha_shape_via.geoms)] -codigo mio
#idxPolMayor=areas.index(max(areas)) -codigo mio
#polyBV=list(alpha_shape_via.geoms)[idxPolMayor] -codigo mio

polyBV = max(alpha_shape_via.geoms, key=lambda x: x.area) #código de ChatGPT

# %%
polyBV

# %%
fig, ax = plt.subplots()
ax.add_patch(PolygonPatch(polyBV, alpha=0.7))
ax.set(xticks = [], yticks = [])
#ax.grid(True)
#ax.set_xlabel('Este')
#ax.set_ylabel('Norte')
ax.set_title('Lille 2 en formato vector')
plt.plot()
#plt.savefig('lille2Vector.png')
# Out:
# /home/xrg/anaconda3/envs/lidargpu/lib/python3.7/site-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])
# []

# %%
axis=trimesh.path.polygons.medial_axis(polyBV)

# %%
[edg,vert]=axis[0],axis[1]

# %%
edg
# Out:
# array([[  1,   3],
#        [  2,   3],
#        [  3,   5],
#        [  4,   5],
#        [  5,   6],
#        [  6,   7],
#        [  7,  11],
#        [ 11,  13],
#        [  8,  12],
#        [ 12,  13],
#        [  8,  15],
#        [  9,  14],
#        [ 14,  15],
#        [ 16,  17],
#        [  0,  18],
#        [ 17,  18],
#        [  0,  19],
#        [ 19,  20],
#        [ 20,  21],
#        [ 21,  24],
#        [ 31,  32],
#        [  9,  25],
#        [ 25,  37],
#        [ 36,  37],
#        [ 26,  44],
#        [ 26,  41],
#        [ 28,  45],
#        [ 45,  47],
#        [ 44,  46],
#        [ 46,  47],
#        [ 49,  51],
#        [ 49,  50],
#        [ 23,  51],
#        [ 29,  50],
#        [ 29,  53],
#        [ 52,  53],
#        [ 54,  55],
#        [ 55,  56],
#        [ 56,  57],
#        [ 24,  57],
#        [ 58,  61],
#        [ 61,  62],
#        [ 63,  65],
#        [ 64,  65],
#        [ 58,  63],
#        [ 10,  71],
#        [ 71,  73],
#        [ 22,  72],
#        [ 71,  72],
#        [ 37,  74],
#        [ 73,  74],
#        [ 76,  77],
#        [ 77,  78],
#        [ 39,  76],
#        [ 40,  78],
#        [ 27,  40],
#        [ 39,  80],
#        [ 79,  80],
#        [ 81,  82],
#        [ 81,  83],
#        [ 41,  42],
#        [ 42,  82],
#        [ 38,  43],
#        [ 38,  84],
#        [ 84,  85],
#        [ 85,  86],
#        [ 88,  89],
#        [ 89,  90],
#        [ 54,  88],
#        [ 52,  90],
#        [ 91,  93],
#        [ 92,  93],
#        [ 23,  92],
#        [ 64,  91],
#        [ 31,  95],
#        [ 95,  96],
#        [ 27,  97],
#        [ 70,  98],
#        [ 98,  99],
#        [100, 101],
#        [ 68, 100],
#        [ 69, 101],
#        [ 30, 103],
#        [102, 103],
#        [ 34, 106],
#        [106, 107],
#        [ 28,  34],
#        [108, 109],
#        [109, 110],
#        [ 36, 110],
#        [ 35, 108],
#        [112, 114],
#        [113, 114],
#        [113, 115],
#        [ 75, 111],
#        [ 75, 112],
#        [ 43, 114],
#        [ 83, 115],
#        [ 87, 116],
#        [ 48, 118],
#        [117, 118],
#        [ 87, 120],
#        [116, 119],
#        [121, 122],
#        [122, 123],
#        [ 86, 121],
#        [120, 123],
#        [124, 125],
#        [ 67,  94],
#        [ 67, 126],
#        [130, 132],
#        [131, 132],
#        [ 96, 130],
#        [ 69, 131],
#        [ 66, 127],
#        [127, 128],
#        [125, 126],
#        [ 94, 136],
#        [135, 136],
#        [137, 139],
#        [138, 139],
#        [ 99, 137],
#        [ 68, 138],
#        [140, 141],
#        [141, 142],
#        [104, 105],
#        [105, 140],
#        [103, 142],
#        [ 60,  62],
#        [ 60, 145],
#        [105, 143],
#        [143, 145],
#        [144, 145],
#        [ 70, 146],
#        [146, 147],
#        [148, 150],
#        [149, 150],
#        [107, 148],
#        [ 35, 149],
#        [151, 154],
#        [151, 152],
#        [152, 153],
#        [111, 152],
#        [156, 157],
#        [118, 159],
#        [158, 159],
#        [160, 161],
#        [160, 163],
#        [162, 164],
#        [163, 164],
#        [124, 162],
#        [129, 161],
#        [128, 129],
#        [ 32, 164],
#        [165, 167],
#        [166, 167],
#        [ 97, 166],
#        [134, 135],
#        [134, 168],
#        [168, 169],
#        [170, 171],
#        [170, 172],
#        [133, 172],
#        [134, 171],
#        [133, 165],
#        [144, 174],
#        [173, 174],
#        [104, 175],
#        [175, 176],
#        [147, 177],
#        [176, 177],
#        [178, 180],
#        [179, 180],
#        [155, 178],
#        [ 79, 179],
#        [155, 181],
#        [181, 183],
#        [156, 182],
#        [182, 183],
#        [184, 187],
#        [184, 185],
#        [186, 187],
#        [119, 187],
#        [158, 185],
#        [157, 186],
#        [188, 189],
#        [188, 190],
#        [169, 189],
#        [ 33, 190],
#        [191, 192],
#        [191, 194],
#        [192, 193],
#        [194, 195],
#        [173, 193],
#        [ 59, 192]])

# %%
vert
# Out:
# array([[ -773.98180134,  -754.46448926],
#        [ -927.99238784, -1048.84320494],
#        [ -926.40644281, -1048.77728959],
#        [ -926.51199289, -1048.52765679],
#        [ -922.18420563, -1047.94507263],
#        [ -924.49709514, -1045.65711994],
#        [ -924.52660895, -1044.87772227],
#        [ -923.60456611, -1043.2968439 ],
#        [ -920.78889919, -1033.48983268],
#        [ -917.64007914, -1026.62001901],
#        [ -904.92866751, -1028.77968949],
#        [ -923.67274955, -1040.37727321],
#        [ -922.20140003, -1035.863801  ],
#        [ -922.22460606, -1038.04972802],
#        [ -918.18164251, -1027.04776193],
#        [ -920.69628998, -1031.39237022],
#        [ -771.14103646,  -760.30369181],
#        [ -771.15267471,  -757.84234997],
#        [ -773.73046463,  -757.60206011],
#        [ -777.31666831,  -754.04285031],
#        [ -777.38157638,  -753.91931278],
#        [ -782.3208572 ,  -753.57559894],
#        [ -903.96988997, -1024.83493407],
#        [ -804.90041019,  -774.64453055],
#        [ -782.83741094,  -754.22838371],
#        [ -916.10011196, -1024.1031872 ],
#        [ -906.60559294,  -980.54698771],
#        [ -877.49036454,  -890.20308782],
#        [ -909.43880666,  -989.98743707],
#        [ -798.51137569,  -767.52111521],
#        [ -814.94111964,  -808.25822398],
#        [ -856.48355252,  -845.43108292],
#        [ -858.72261538,  -849.57829883],
#        [ -853.78882645,  -877.87048194],
#        [ -910.37318156,  -994.27078069],
#        [ -914.08529319, -1008.57394649],
#        [ -914.55379482, -1018.50500853],
#        [ -913.7339364 , -1022.1357499 ],
#        [ -899.38788413,  -956.50402487],
#        [ -881.72016161,  -901.06364225],
#        [ -877.79286998,  -892.55465734],
#        [ -905.52327316,  -976.15287047],
#        [ -905.38880036,  -976.02001818],
#        [ -900.03366088,  -957.79137716],
#        [ -906.81568085,  -980.75521762],
#        [ -909.09826653,  -989.63728057],
#        [ -907.87379627,  -985.15673847],
#        [ -908.15499809,  -985.44197577],
#        [ -909.66373502,  -924.11952433],
#        [ -801.64196567,  -771.01958548],
#        [ -800.60548816,  -768.80592317],
#        [ -803.84343289,  -772.36896825],
#        [ -795.30213166,  -763.93981008],
#        [ -797.42865311,  -765.22728285],
#        [ -791.19558076,  -757.72989038],
#        [ -787.8297942 ,  -754.49979583],
#        [ -787.51811118,  -754.44968002],
#        [ -787.50582454,  -754.45491529],
#        [ -816.02131795,  -786.60322332],
#        [ -835.87866111,  -787.25208154],
#        [ -821.25712757,  -793.84161678],
#        [ -817.43589428,  -789.2649764 ],
#        [ -819.30841641,  -790.30751851],
#        [ -814.41274076,  -785.59623945],
#        [ -811.30449693,  -781.83631646],
#        [ -813.23019821,  -783.02878479],
#        [ -876.36096676,  -844.5567298 ],
#        [ -864.12398133,  -862.85875374],
#        [ -847.64874485,  -828.08489524],
#        [ -850.18641682,  -832.53322333],
#        [ -838.845406  ,  -816.41709325],
#        [ -907.02640115, -1024.54760655],
#        [ -906.31301435, -1024.31202412],
#        [ -910.64533204, -1023.84076235],
#        [ -913.06612095, -1022.31711898],
#        [ -893.63756635,  -962.09881277],
#        [ -881.46572547,  -898.89338987],
#        [ -879.78881059,  -896.89627778],
#        [ -879.50042153,  -894.55028221],
#        [ -883.78603101,  -905.49135467],
#        [ -883.55310639,  -903.26223929],
#        [ -904.19513125,  -971.4848741 ],
#        [ -904.26687915,  -971.55490419],
#        [ -902.99721351,  -966.89881842],
#        [ -899.40466612,  -952.9475409 ],
#        [ -898.16422765,  -951.0498398 ],
#        [ -898.14376594,  -948.39588062],
#        [ -894.66607615,  -937.32711327],
#        [ -791.34431258,  -757.7848548 ],
#        [ -793.51384612,  -761.26336424],
#        [ -794.22823973,  -761.68999262],
#        [ -810.22634916,  -779.51732138],
#        [ -807.01531502,  -775.94272678],
#        [ -808.0621689 ,  -778.18538432],
#        [ -865.46296588,  -864.22473103],
#        [ -856.49055546,  -845.2322745 ],
#        [ -854.3167291 ,  -841.26293607],
#        [ -875.81233237,  -888.25495276],
#        [ -839.78950761,  -816.89174822],
#        [ -841.75831618,  -820.2230139 ],
#        [ -847.96424002,  -828.25649282],
#        [ -850.19934564,  -832.1761099 ],
#        [ -816.42444743,  -808.79140375],
#        [ -816.29211728,  -808.21482714],
#        [ -828.22465813,  -804.06601695],
#        [ -825.16088478,  -800.14609924],
#        [ -910.6780403 ,  -994.59257597],
#        [ -911.52576593,  -998.6965971 ],
#        [ -913.90068001, -1009.14087335],
#        [ -914.66935639, -1013.37922378],
#        [ -914.13922334, -1015.31712368],
#        [ -891.17705594,  -963.37254609],
#        [ -895.86507636,  -962.49262489],
#        [ -901.62023796,  -962.32833057],
#        [ -899.90844933,  -960.68215049],
#        [ -902.80394859,  -966.71431073],
#        [ -894.49408478,  -932.51282764],
#        [ -909.10444413,  -922.81112935],
#        [ -908.81917142,  -923.63156739],
#        [ -895.06721333,  -931.18917643],
#        [ -895.57466398,  -938.70740278],
#        [ -896.86973215,  -946.49296326],
#        [ -896.84516301,  -943.75164953],
#        [ -895.6588605 ,  -941.99303447],
#        [ -861.34075488,  -853.62086127],
#        [ -862.31780185,  -858.30351293],
#        [ -863.50873148,  -859.56367191],
#        [ -875.45362865,  -845.93283844],
#        [ -873.17233305,  -846.52375016],
#        [ -872.926167  ,  -846.92164139],
#        [ -854.35697996,  -840.58225081],
#        [ -852.28785606,  -836.27667369],
#        [ -852.26362523,  -836.80418132],
#        [ -872.19341623,  -880.38114226],
#        [ -867.1161348 ,  -872.87027752],
#        [ -866.41178369,  -869.10594885],
#        [ -866.46393257,  -868.91149665],
#        [ -842.73665176,  -820.71384589],
#        [ -845.51557528,  -824.46435205],
#        [ -844.71947568,  -824.05841714],
#        [ -822.93017293,  -801.60698985],
#        [ -820.44043119,  -805.07010152],
#        [ -817.4396054 ,  -806.46899933],
#        [ -825.24387556,  -799.78919511],
#        [ -825.70492782,  -795.43936401],
#        [ -824.94630502,  -796.31292338],
#        [ -836.83758926,  -813.10217348],
#        [ -836.02019804,  -812.69316402],
#        [ -912.01101567,  -999.21374112],
#        [ -913.15951886, -1003.8691996 ],
#        [ -912.83993896, -1003.52012285],
#        [ -888.75718137,  -962.73119947],
#        [ -888.99225843,  -962.97758324],
#        [ -887.75146973,  -965.0657834 ],
#        [ -885.57773395,  -962.44278527],
#        [ -887.46396796,  -914.50780734],
#        [ -891.002907  ,  -923.59985489],
#        [ -893.95151848,  -927.61938784],
#        [ -905.99585051,  -925.68782665],
#        [ -907.53611614,  -924.10217166],
#        [ -868.55343999,  -848.3811706 ],
#        [ -868.89476405,  -848.50120807],
#        [ -861.70529385,  -852.14495487],
#        [ -861.84244938,  -851.17114646],
#        [ -861.5927467 ,  -851.42723741],
#        [ -873.4624074 ,  -881.54100475],
#        [ -875.50219747,  -885.86034543],
#        [ -874.16045694,  -884.31362216],
#        [ -862.14621176,  -874.58209185],
#        [ -861.30438292,  -874.41728458],
#        [ -868.16455378,  -874.24110429],
#        [ -867.86407386,  -873.55188892],
#        [ -871.36506804,  -877.18785471],
#        [ -831.76167866,  -791.05029154],
#        [ -830.90664984,  -792.68249683],
#        [ -830.99143266,  -805.42702066],
#        [ -833.14693868,  -808.92307257],
#        [ -833.98046063,  -809.33607713],
#        [ -887.25080551,  -911.78488056],
#        [ -885.46251033,  -907.57487867],
#        [ -885.67316906,  -909.79259809],
#        [ -888.84727119,  -916.27812895],
#        [ -890.74953279,  -921.18947864],
#        [ -889.06017495,  -918.99692215],
#        [ -901.53444284,  -927.28227383],
#        [ -902.66691215,  -926.2241806 ],
#        [ -894.88461749,  -928.20244999],
#        [ -895.09586111,  -928.47782766],
#        [ -856.7325169 ,  -876.37612504],
#        [ -857.7835156 ,  -876.5433034 ],
#        [ -855.10159691,  -877.94959483],
#        [ -839.60425815,  -787.38506918],
#        [ -836.28279979,  -788.03730469],
#        [ -835.62189059,  -789.38551194],
#        [ -840.73940037,  -787.82476958],
#        [ -840.92400037,  -788.15310767]])

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*vert))
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
plt.show()

# %%
fig, ax = plt.subplots()
#ax.scatter(vert[0])
plt.plot(vert[0][0], vert[0][1] ,'ro')
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
plt.show()

# %%
fig, ax = plt.subplots()
#ax.scatter(vert[0])
plt.plot(vert[-1][0], vert[-1][1] ,'ro')
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
plt.show()

# %% [markdown]
# Las últimas dos celdas permiten ver que e orden de los puntos calculados por skeleton no corresponde con el orden geomtetrico necesario para el ejercicio, es decir el inicio y final de la via. Por eso debe usarse matplotlib interactivo.

# %% [markdown]
# # matplotlib Interactivo

# %%
# %matplotlib widget

# %%
list(enumerate(vert))[0]

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*vert))
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))

#agregando etiquetas a cada punto: su orden en la lista de vertices.
for eti, coordenadas in enumerate(vert):
    plt.annotate(str(eti), coordenadas)

plt.show()

# %% [markdown]
# con esto se identifica que el punto inicial de la via es el 1 y el final el 16. Gracias a esto ahora será posible utilizar networkx para que calcule la ruta entre eso dos puntos.

# %% [markdown]
# # probando networkx

# %%
G = nx.cycle_graph(7)

# %%
G[0]

# %%
nx.draw(G)

# %%
ggg=nx.from_edgelist(edg)

# %%
ggg

# %%
print(ggg)
# Out:
# Graph with 196 nodes and 195 edges

# %%
eje=list(nx.shortest_simple_paths(ggg, 1, 16)) 

# AQUI ES DONDE SE CALCULA REALMENTE EL EJE, INDICANDO EL PUNTO INICIAL Y EL FINAL.
# ENTONCES ES NECESARIO ENCONTAR UNA ESTRATEGIA QUE PERMITA IDENTIFICAR FACILMENTE CUALES SON ESOS PUNTOS.

# %%
ejeShapely=LineString(vert[tuple(eje)])

# %%
ejeShapely

# %%
ejsh_sv=ejeShapely.simplify(2, preserve_topology=True)

# %%
ejsh_sv

# %%
fig, ax = plt.subplots()
plt.plot(*ejsh_sv.xy)
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
plt.show()

# %%
x_eje=vert[tuple(eje)][:,0]
y_eje=vert[tuple(eje)][:,1]

# %%
tck,u=interpolate.splprep([x_eje,y_eje],s=100)

# %%
new_points = interpolate.splev(u, tck)

# %%
c_ejsv=np.concatenate((new_points[0].reshape((len(new_points[0]),1)),new_points[1].reshape((len(new_points[1]),1))) ,axis=1)

# %%
ejeSuave=LineString(c_ejsv)

# %%
ejeSuave.length
# Out:
# 350.1815480132809

# %%
fig, ax = plt.subplots()
plt.plot(*ejeSuave.xy, 'r')
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
ax.set_xlabel('Este')
ax.set_ylabel('Norte')
ax.set_title('Lille 2 en formato vector y eje medio')
plt.plot()
#plt.savefig('lille2Vector_EjeMedio.png')
# Out:
# []

# %%
p1=ejeSuave.parallel_offset(2.9,'left')
p2=ejeSuave.parallel_offset(1.1,'left')
p3=ejeSuave.parallel_offset(1.1,'right')
p4=ejeSuave.parallel_offset(2.9,'right')

perfiles=[p1,p2,p3,p4]
etiquetas=['Perfil 1', 'Perfil 2', 'Perfil 3', 'Perfil 4']

# %%
fig, ax = plt.subplots()
#plt.plot(*ejeSuave.xy, label='Eje medio')
for perfil, etiqueta in zip(perfiles, etiquetas):
    plt.plot(*perfil.xy, label=etiqueta)
ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
ax.set_xlabel('Este')
ax.set_ylabel('Norte')
ax.set_title('Trazado planimetrico de los perfiles de Lille2')
plt.legend()
plt.plot()
#plt.savefig('Planimetria_PerfilesLille2.png')
#plt.show()
# Out:
# []

# %% [markdown]
# # aqui

# %%
geoseries_shapely=gpd.GeoSeries(perfiles)
df_shapely=gpd.GeoDataFrame(geoseries_shapely)
df_shapely.columns=['geometry']

# %%
df_shapely
# Out:
#                                             geometry
# 0  LINESTRING (-930.088 -1047.868, -929.332 -1046...
# 1  LINESTRING (-928.563 -1048.825, -927.790 -1047...
# 2  LINESTRING (-769.989 -759.984, -772.005 -758.2...
# 3  LINESTRING (-771.154 -761.355, -773.086 -759.7...

# %%
df_shapely.plot()
# Out:
# <AxesSubplot:>

# %%
#df_shapely.to_file('shapes/perfilesLille2.shp')

# %%
#ejeSuave=ejeShapely.simplify(8, preserve_topology=False)

# %%
#fig, ax = plt.subplots()
#plt.plot(*ejeSuave.xy)
#ax.add_patch(PolygonPatch(polyBV, alpha=0.2))
#plt.show()

# %% [raw]
# https://gidahatari.com/ih-es/como-unir-lineas-y-densificar-vertices-con-python-fiona-shapely-tutorial

# %% [raw]
# tener en cuenta esa pagina para resolver el problema de suavizado del perfil.

# %% [markdown]
# # crear dx

# %%
def ptosPerfil(linea, dx):
    # aqui no no coge el ultimo punto de la linea a menos que range sea exacto
    puntos=np.array([np.ravel(np.array(linea.interpolate(i*dx).coords)) for i in range(int(linea.length/dx)+1)]) 
    return puntos

# %% [raw]
# puntosEjeMedio=ptosPerfil(ejeSuave,0.25)

# %% [raw]
# puntosEjeMedio

# %%
dx=0.25
puntosPerfiles=np.array([ptosPerfil(e,dx) for e in (perfiles)],dtype=object)

# %%
puntosPerfiles
# Out:
# array([array([[ -930.08775913, -1047.86797234],
#               [ -929.95484992, -1047.65622924],
#               [ -929.8219407 , -1047.44448614],
#               ...,
#               [ -767.89579644,  -756.51330478],
#               [ -767.70527762,  -756.67517689],
#               [ -767.5147588 ,  -756.837049  ]]),
#        array([[ -928.56320883, -1048.82491872],
#               [ -928.43029961, -1048.61317562],
#               [ -928.29739039, -1048.40143252],
#               ...,
#               [ -768.99644523,  -757.94012268],
#               [ -768.80592641,  -758.10199478],
#               [ -768.61540759,  -758.26386689]]),
#        array([[ -769.98892285,  -759.98372947],
#               [ -770.17944167,  -759.82185736],
#               [ -770.36996049,  -759.65998525],
#               ...,
#               [ -926.41164132, -1049.53533167],
#               [ -926.54455054, -1049.74707476],
#               [ -926.67745976, -1049.95881786]]),
#        array([[ -771.15440202,  -761.35546498],
#               [ -771.34492084,  -761.19359287],
#               [ -771.53543966,  -761.03172076],
#               ...,
#               [ -924.80390742, -1050.35975486],
#               [ -924.93681664, -1050.57149796],
#               [ -925.06972586, -1050.78324106]])], dtype=object)

# %% [markdown]
# # Buscando en NP

# %%
ppl="""
    {
        "pipeline":[
            "superficiesRodadura/npm3d_parisLille/lille2.ply"
        ]  
    }"""

# probar con diferentes valores de knn 

pipeline = pdal.Pipeline(ppl)
count = pipeline.execute()

# %%
print('numero de puntos de la nube cargada: '+str(count))
# Out:
# numero de puntos de la nube cargada: 11816213

# %%
dtst_ini=pipeline.arrays[0]
encbz_ini=pipeline.arrays[0].dtype.names

# %%
print('DATOS SUBIDOS CON PDAL\n')
print(encbz_ini)
print(dtst_ini[:3])
# Out:
# DATOS SUBIDOS CON PDAL
#
# ('X', 'Y', 'Z', 'scalar_class')
# [(-774.49053955, -752.46435547, 27.53279495, 2.0202e+08)
#  (-774.42498779, -752.54907227, 27.53769302, 2.0202e+08)
#  (-774.34057617, -752.64984131, 27.53412437, 2.0202e+08)]

# %%
enc_xyzSR=('X', 'Y', 'Z')

# %%
xyzSR=np.zeros((len(dtst_ini),3))

# %%
for e in range(len(xyzSR)):
    for i in range(len(enc_xyzSR)):
        xyzSR[e,i]=dtst_ini[e][encbz_ini.index(enc_xyzSR[i])]

# %%
xyzSR.shape
# Out:
# (11816213, 3)

# %%
xySR=xyzSR[:,0:2]
xySR
# Out:
# array([[ -774.49053955,  -752.46435547],
#        [ -774.42498779,  -752.54907227],
#        [ -774.34057617,  -752.64984131],
#        ...,
#        [ -929.52288818, -1052.95532227],
#        [ -930.0760498 , -1052.54638672],
#        [ -930.04248047, -1052.86340332]])

# %% [raw]
# len(ptosPerfil)
# ptosPerfil[0]
# xyzSR[spatial.KDTree(xySR).query(ptosPerfil[0])[1]]

# %%
kd=spatial.KDTree(xySR)

# %%
kd

# %%
def extraccz(arkd, coordperf, nbtt):
    z=[]
    for e in coordperf:
        qry=arkd.query(e)
        #d=np.distancia [0] tener en cuenta pero no construir todavis, para la discusion debe hacerse
        z.append(nbtt[qry[1]][-1])
    return z

# %% [raw]
# zsEjeMedio=extraccz(kd, puntosEjeMedio, xyzSR)

# %%
zsPerfiles=np.array([extraccz(kd,e,xyzSR) for e in puntosPerfiles],dtype=object)

# %%
zsPerfiles
# Out:
# array([list([21.10146141052246, 21.097864151000977, 21.111736297607422, 21.111736297607422, 21.10890769958496, 21.111122131347656, 21.111122131347656, 21.06590461730957, 21.060565948486328, 21.060565948486328, 21.09716796875, 21.082555770874023, 21.08041000366211, 21.075185775756836, 21.032777786254883, 21.06644630432129, 21.034202575683594, 21.081710815429688, 21.048662185668945, 21.083215713500977, 21.07497215270996, 21.054101943969727, 21.080820083618164, 21.104875564575195, 21.113330841064453, 21.089750289916992, 21.061750411987305, 21.113740921020508, 21.047237396240234, 21.066085815429688, 21.094425201416016, 21.07883644104004, 21.11821937561035, 21.078641891479492, 21.07894515991211, 21.088502883911133, 21.08840560913086, 21.091323852539062, 21.083738327026367, 21.08321762084961, 21.110097885131836, 21.112886428833008, 21.086036682128906, 21.13555335998535, 21.074565887451172, 21.1087703704834, 21.09623908996582, 21.103456497192383, 21.090499877929688, 21.101829528808594, 21.08449363708496, 21.085721969604492, 21.085094451904297, 21.102798461914062, 21.109149932861328, 21.12408447265625, 21.12405014038086, 21.116334915161133, 21.123056411743164, 21.114898681640625, 21.106016159057617, 21.089542388916016, 21.076553344726562, 21.067739486694336, 21.096599578857422, 21.064233779907227, 21.120542526245117, 21.105146408081055, 21.098337173461914, 21.160749435424805, 21.106773376464844, 21.161293029785156, 21.15560531616211, 21.128244400024414, 21.121152877807617, 21.1541805267334, 21.110639572143555, 21.129627227783203, 21.120426177978516, 21.126785278320312, 21.126605987548828, 21.157779693603516, 21.172231674194336, 21.180042266845703, 21.176156997680664, 21.18609619140625, 21.177106857299805, 21.190608978271484, 21.183582305908203, 21.185850143432617, 21.175634384155273, 21.178176879882812, 21.16347885131836, 21.157060623168945, 21.186111450195312, 21.17523765563965, 21.17315673828125, 21.188329696655273, 21.187456130981445, 21.19603729248047, 21.168758392333984, 21.17266082763672, 21.14790916442871, 21.159347534179688, 21.14942741394043, 21.14488983154297, 21.156845092773438, 21.162382125854492, 21.156986236572266, 21.168012619018555, 21.151473999023438, 21.169906616210938, 21.159658432006836, 21.169757
#       dtype=object)

# %%
def perfz(pfxy,z):
    pft=np.array([np.concatenate((e,np.array(i).reshape(len(i),1)),axis=1) for e,i in zip(pfxy,z)],dtype=object)
    return pft

# %%
perfilesConZ=perfz(puntosPerfiles,zsPerfiles)

# %%
perfilesConZ
# Out:
# array([array([[ -930.08775913, -1047.86797234,    21.10146141],
#               [ -929.95484992, -1047.65622924,    21.09786415],
#               [ -929.8219407 , -1047.44448614,    21.1117363 ],
#               ...,
#               [ -767.89579644,  -756.51330478,    27.41337585],
#               [ -767.70527762,  -756.67517689,    27.43748093],
#               [ -767.5147588 ,  -756.837049  ,    27.43748093]]),
#        array([[ -928.56320883, -1048.82491872,    21.1661377 ],
#               [ -928.43029961, -1048.61317562,    21.18850136],
#               [ -928.29739039, -1048.40143252,    21.14350891],
#               ...,
#               [ -768.99644523,  -757.94012268,    27.44221497],
#               [ -768.80592641,  -758.10199478,    27.41427422],
#               [ -768.61540759,  -758.26386689,    27.41015816]]),
#        array([[ -769.98892285,  -759.98372947,    27.39437103],
#               [ -770.17944167,  -759.82185736,    27.40439415],
#               [ -770.36996049,  -759.65998525,    27.37655258],
#               ...,
#               [ -926.41164132, -1049.53533167,    21.30305672],
#               [ -926.54455054, -1049.74707476,    21.22475815],
#               [ -926.67745976, -1049.95881786,    21.22876167]]),
#        array([[ -771.15440202,  -761.35546498,    27.25754738],
#               [ -771.34492084,  -761.19359287,    27.26241493],
#               [ -771.53543966,  -761.03172076,    27.24917984],
#               ...,
#               [ -924.80390742, -1050.35975486,    21.30522537],
#               [ -924.93681664, -1050.57149796,    21.22187996],
#               [ -925.06972586, -1050.78324106,    21.30104065]])],
#       dtype=object)

# %%
p1z=LineString(perfilesConZ[0])
p2z=LineString(perfilesConZ[1])
p3z=LineString(perfilesConZ[2])
p4z=LineString(perfilesConZ[3])
perfiles_Z=[p1z,p2z,p3z,p4z]

# %%
from shapely.geometry import MultiPoint

# %%
p1z_pp=MultiPoint(perfilesConZ[0])
p2z_pp=MultiPoint(perfilesConZ[1])
p3z_pp=MultiPoint(perfilesConZ[2])
p4z_pp=MultiPoint(perfilesConZ[3])
perfiles_enPuntos_Z=[p1z_pp,p2z_pp,p3z_pp,p4z_pp]

# %%
geoseries_shapely=gpd.GeoSeries(perfiles_Z)
df_shapely=gpd.GeoDataFrame(geoseries_shapely)
df_shapely.columns=['geometry']

# %%
df_shapely
# Out:
#                                             geometry
# 0  LINESTRING Z (-930.088 -1047.868 21.101, -929....
# 1  LINESTRING Z (-928.563 -1048.825 21.166, -928....
# 2  LINESTRING Z (-769.989 -759.984 27.394, -770.1...
# 3  LINESTRING Z (-771.154 -761.355 27.258, -771.3...

# %%
df_shapely.plot()
# Out:
# <AxesSubplot:>

# %%
df_shapely.to_file('shapes/perfilesLille2_ubicacionFinal')

# %%
x=[]
for i,e in zip(perfiles, zsPerfiles):
    x.append(np.array([np.linspace(0,i.length,len(e))]))

# %%
zsPerfiles[-1].reverse()
zsPerfiles[-2].reverse()

# %% [raw]
# x[0].shape[-1]
# x.reshape()

# %% [raw]
# #x=range(0,int(ejeSuave.length),dx)
# x=np.linspace(0,ejeSuave.length,len(zsEjeMedio))

# %%
fig, ax = plt.subplots()
for e, i, etq in zip(x,zsPerfiles, etiquetas):
    plt.plot(e.reshape(e.shape[-1] ,1) ,i, label=etq)
ax.set_xlabel('dx (m)')
ax.set_ylabel('Z (m)')
ax.set_title('Vista global perfiles de Lille2 con Z más cercana')
plt.legend()
plt.savefig('PerfilesLille2_zmasCercana.png')
#ax.plot(x,zsEjeMedio)

# %%
fig, ax = plt.subplots()
for e, i, etq in zip(x,zsPerfiles, etiquetas):
    plt.plot(e.reshape(e.shape[-1] ,1) ,i, label=etq)
ax.set_xlabel('dx (m)')
ax.set_ylabel('Z (m)')
ax.set_title('Zoom abscisa 100 a 110 en perfiles de Lille 2 para Z más cercana')
plt.xlim(100, 110)
plt.ylim(20.93, 21.1)
plt.legend()
plt.savefig('PerfilesLille2_zoom_ZmasCercana.png')
#ax.plot(x,zsEjeMedio)

# %%
zsPerfiles
# Out:
# array([list([21.10146141052246, 21.097864151000977, 21.111736297607422, 21.111736297607422, 21.10890769958496, 21.111122131347656, 21.111122131347656, 21.06590461730957, 21.060565948486328, 21.060565948486328, 21.09716796875, 21.082555770874023, 21.08041000366211, 21.075185775756836, 21.032777786254883, 21.06644630432129, 21.034202575683594, 21.081710815429688, 21.048662185668945, 21.083215713500977, 21.07497215270996, 21.054101943969727, 21.080820083618164, 21.104875564575195, 21.113330841064453, 21.089750289916992, 21.061750411987305, 21.113740921020508, 21.047237396240234, 21.066085815429688, 21.094425201416016, 21.07883644104004, 21.11821937561035, 21.078641891479492, 21.07894515991211, 21.088502883911133, 21.08840560913086, 21.091323852539062, 21.083738327026367, 21.08321762084961, 21.110097885131836, 21.112886428833008, 21.086036682128906, 21.13555335998535, 21.074565887451172, 21.1087703704834, 21.09623908996582, 21.103456497192383, 21.090499877929688, 21.101829528808594, 21.08449363708496, 21.085721969604492, 21.085094451904297, 21.102798461914062, 21.109149932861328, 21.12408447265625, 21.12405014038086, 21.116334915161133, 21.123056411743164, 21.114898681640625, 21.106016159057617, 21.089542388916016, 21.076553344726562, 21.067739486694336, 21.096599578857422, 21.064233779907227, 21.120542526245117, 21.105146408081055, 21.098337173461914, 21.160749435424805, 21.106773376464844, 21.161293029785156, 21.15560531616211, 21.128244400024414, 21.121152877807617, 21.1541805267334, 21.110639572143555, 21.129627227783203, 21.120426177978516, 21.126785278320312, 21.126605987548828, 21.157779693603516, 21.172231674194336, 21.180042266845703, 21.176156997680664, 21.18609619140625, 21.177106857299805, 21.190608978271484, 21.183582305908203, 21.185850143432617, 21.175634384155273, 21.178176879882812, 21.16347885131836, 21.157060623168945, 21.186111450195312, 21.17523765563965, 21.17315673828125, 21.188329696655273, 21.187456130981445, 21.19603729248047, 21.168758392333984, 21.17266082763672, 21.14790916442871, 21.159347534179688, 21.14942741394043, 21.14488983154297, 21.156845092773438, 21.162382125854492, 21.156986236572266, 21.168012619018555, 21.151473999
#       dtype=object)

# %%
qq=[]
for i in zsPerfiles:
    b=np.array(i).reshape(len(i),1)
    #kk=np.concatenate((a,b), axis=1)
    qq.append(b)
qq

# %%
for e in range(len(qq)):
    DF = pd.DataFrame(qq[e])
    txt='p{}_lille2_Zcerc.csv'.format(e+1)
    DF.to_csv(txt)

# %%
DF = pd.DataFrame(qq[0])
DF.to_csv("lille2Zcerc_p1.csv")

# %%
a=9

# %%
txt='my name is {a}'.format(a=0)

# %%
txt

# %%
int(ejeSuave.length/dx)+1

# %%
ejeSuave.length

# %%
np.where(np.all(coorsEjeSuave[1]==xySR, axis=1))

# %%
d=1

# %%
coorsEjeSuaveF=np.around(coorsEjeSuave,decimals=d)
xySR_Sv=np.around(xySR,decimals=d)

# %%
np.where(np.all(coorsEjeSuaveF[2]==xySR_Sv, axis=1))

# %%
np.where(coorsEjeSuaveF[0][0] ==xySR_Sv[:,0])

# %%
np.where(coorsEjeSuaveF[0][1] ==xySR_Sv[:,1])

# %% [markdown]
# # Utilizar PDAL

# %%
https://pdal.io/en/2.6.0/stages/filters.neighborclassifier.html#filters-neighborclassifier

# %% [markdown]
# # construccion de esqueleto en forma de lineas

# %%
dfs = trimesh.graph.traversals(edg, mode='dfs')
dfs_connected = trimesh.graph.fill_traversals(dfs, edges=edg)

# %%
dfs

# %%
dfs_connected

# %% [raw]
# for c in dfs_connected:
#     line = LineString(vert[c])
#     plt.plot(*line.xy)
# plt.title('Shapely Irregular')
# plt.show()

# %% [raw]
# for c in dfs_connected:
#     line = LineString(vert[c])
#     lineSmooth=line.simplify(0.9, preserve_topology=True)
#     plt.plot(*lineSmooth.xy)
# plt.title('Shapely Simplify')
# plt.show()

# %%
lineas=[LineString(vert[i]) for i in dfs_connected]

# %%
lineSmooth=[i.simplify(0.9, preserve_topology=True) for i in lineas]

# %%
for c in lineas:
    plt.plot(*c.xy)
plt.title('Axis ploteo propio irregular')
plt.show()

# %%
for c in lineSmooth:
    plt.plot(*c.xy)
plt.title('Axis ploteo propio suavizado')
plt.show()

# %%
lineas # revisar como paso esto a numpy para revisar cada coordenada

# %%
# !!IMPORTANTE!! asi veo las coords de una linea
np.array(lineSmooth[0].coords)

# %%
import geopandas as gpd

# %%
geoseries_shapely=gpd.GeoSeries(lineSmooth)
df_shapely=gpd.GeoDataFrame(geoseries_shapely)
df_shapely.columns=['geometry']

# %%
df_shapely

# %%
df_shapely.plot()

# %%
df_shapely.to_file('shapes/sekeletonLille2_Suavizado.shp')

# %% [markdown]
# # ploteo de solo borde del poligono

# %%
#x_sh, y_sh = alpha_shape_via.geoms[1].exterior.xy
x_sh, y_sh = alpha_shape_via[3].exterior.xy
plt.plot(x_sh, y_sh, c="red")
plt.show()

# %%
x_sh, y_sh = alpha_shape_via.geoms[0].exterior.xy
plt.plot(x_sh, y_sh, c="red")
plt.show()

# %%
list(alpha_shape_via.boundary.coords)

# %%
alpha_shape_via.boundary
